# %% [markdown]
# <img src="_pictures/techlab006.png">

# %% [markdown]
# # -------------------------------- what the JuPyter? ---------------------------------------

# %% [markdown]
# ## what a JuPyter Notebook does ...
#
# - Supports e.g. Python, R, ...
# - Runs the code in cells rather than in complete scripts
# - Let's you interact with and explore data directly in the Notebook
# - Let's you add additional text/information/pictures using Markdown (also mathematical notation with $\LaTeX$
# - Creates reports with inline graphics and analysis, comments, etc. and export them to PDF, HTML, ...
# - Runs locally on your laptop and is displayed in your browser
# - Remote access e.g. on the Google Cloud (-> DataLab) and pull data from e.g. BigQuery directly
# - Allows easy collaboration on Notebooks
# - Transformation of huge datasets only limited by the machine it's running on
#
# ## ... & what a JuPyter Notebook _doesn't_
#
# - insert formulas at the click of a button (-> some basic coding knowledge is required)
# - build the report diretly into the data tables (as in Excel)
# - play music

# %%
import pandas as pd

# %%
data = pd.read_excel('Ananas Export.xlsx', sheet_name="TwitterData")
data
# Out:
#                     Date       Screen Name                Full Name  \
# 0    2019-02-10 11:01:50        @ATMagambo      Abduh T Magambo ATM
# 1    2019-02-10 11:01:05    @greenpeaceusa           Greenpeace USA
# 2    2019-02-10 11:00:58    @greenpeace_gr        Greenpeace Greece
# 3    2019-02-10 11:00:41       @Greenpeace               Greenpeace
# 4    2019-02-10 11:00:24    @greenpeace_gr        Greenpeace Greece
# 5    2019-02-10 10:59:23       @UnholyGene                        🐱
# 6    2019-02-10 10:58:41          @orla_rh                     orla
# 7    2019-02-10 10:57:57     @JavierRicoNi              Javier Rico
# 8    2019-02-10 10:57:03       @Cynthia__Z     Closer to the Edge 🎶
# 9    2019-02-10 10:55:51        @MatiCaaii                   Matii🎩
# 10   2019-02-10 10:55:46        @gbcimmino   Giovanbattista Cimmino
# 11   2019-02-10 10:53:38        @mmmiquel_         Miquel Ballester
# 12   2019-02-10 10:51:13     @CocoaDChanel      Democracia y Chanel
# ...

# %% [markdown]
# ### where to find more
# TechLab Repositories on Github: https://github.com/orgs/greenpeace/teams/gptechlab/repositories
#
# TechLab email: techlab-group@greenpeace.org
